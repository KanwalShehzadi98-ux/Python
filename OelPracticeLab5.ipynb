# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/DELL/Downloads/CricketTestMatchData.csv",encoding="utf-8")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 66      V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29  15708
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df.rename(columns={'NO':'Not Out','HS':'High Score','BF':'Balls Faced','SR':'Strike Rate'})
# Out:
#                Player       Span  Mat  Inns  Not Out  Runs High Score    Ave  \
# 0    DG Bradman (AUS)  1928-1948   52    80       10  6996        334  99.94
# 1      HC Brook (ENG)  2022-2023   12    20        1  1181        186  62.15
# 2      AC Voges (AUS)  2015-2016   20    31        7  1485       269*  61.87
# 3     RG Pollock (SA)  1963-1970   23    41        4  2256        274  60.97
# 4     GA Headley (WI)  1930-1954   22    40        4  2190       270*  60.83
# ..                ...        ...  ...   ...      ...   ...        ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205       13  9265        277  48.25
# 63  WH Ponsford (AUS)  1924-1934   29    48        4  2122        266  48.22
# 64    SJ McCabe (AUS)  1930-1938   39    62        5  2748        232  48.21
# 65   DR Jardine (ENG)  1928-1934   22    33        6  1296        127  48.00
# 66      V Kohli (IND)  2011-2023  111   187       11  8676       254*  49.29
#
# ...

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  91.76    4   7  1   141  23
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4  56.00   10   5  2  104+   1

# %%
df.isnull()
# Out:
#     Player   Span    Mat   Inns     NO   Runs     HS    Ave     BF     SR  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 62   False  False  False  False  False  False  False  False  False  False
# 63   False  False  False  False  False  False  False  False  False  False
# 64   False  False  False  False  False  False  False  False  False  False
# 65   False  False  False  False  False  False  False  False  False  False
# 66   False  False  False  False  False  False  False  False  False  False
#
#       100     50      0     4s     6s
# 0   False  False  False  False  False
# ...

# %%
df.isnull().any()
# Out:
# Player    False
# Span      False
# Mat       False
# Inns      False
# NO        False
# Runs      False
# HS        False
# Ave       False
# BF         True
# SR         True
# 100       False
# 50        False
# 0         False
# 4s        False
# 6s        False
# dtype: bool

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 8             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 9            SPD Smith (AUS)  2010-2023  102   181  22   9320   239  58.61
# 10          WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# ...

# %%
df[df["BF"].isna()==1]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave   BF  \
# 8         ED Weekes (WI)  1948-1958   48    81   5  4455   207  58.61  NaN
# 16       CL Walcott (WI)  1948-1960   44    74   7  3798   220  56.68  NaN
# 58  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79  NaN
#
#     SR  100  50  0    4s  6s
# 8  NaN   15  19  6  258+   2
# 16 NaN   15  14  1  107+  11
# 58 NaN    5   6  3   51+   0

# %%
df[df["BF"].isna()]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave   BF  \
# 8         ED Weekes (WI)  1948-1958   48    81   5  4455   207  58.61  NaN
# 16       CL Walcott (WI)  1948-1960   44    74   7  3798   220  56.68  NaN
# 58  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79  NaN
#
#     SR  100  50  0    4s  6s
# 8  NaN   15  19  6  258+   2
# 16 NaN   15  14  1  107+  11
# 58 NaN    5   6  3   51+   0

# %%
df["BF"].fillna(0)
# Out:
# 0      9800+
# 1       1287
# 2       2667
# 3      1707+
# 4       416+
# 5      6558+
# 6      1288+
# 7      4957+
# 8          0
# 9      17292
# 10     7491+
# 11     4063+
# 12     4063+
# 13     22882
# 14      2395
# 15     5363+
# 16         0
# 17     2844+
# 18     28903
# 19      178+
# 20     15785
# 21      665+
# 22      1823
# 23    13079+
# 24      108+
# 25    29437+
# 26      7146
# 27     19753
# 28    15164+
# 29    15164+
# 30     31258
# 31     14372
# 32     19375
# 33     22782
# 34     2035+
# 35     10636
# 36     12436
# 37     27395
# 38    14184+
# 39     22461
# 40      2764
# 41     14349
# 42     16077
# 43    27002+
# 44     20113
# 45     9613+
# 46      2719
# 47     2731+
# 48     22959
# 49     16345
# 50      488+
# 51      619+
# 52     10441
# 53     15708
# 54      2445
# 55     15456
# 56      885+
# 57      158+
# 58         0
# 59     11641
# 60     1799+
# 61     8662+
# 62     15525
# 63     3118+
# 64     3217+
# 65     2110+
# ...

# %%
df["SR"].fillna(0)
# Out:
# 0     58.60
# 1     91.76
# 2     55.68
# 3     54.48
# 4     56.00
# 5     34.59
# 6     45.88
# 7     42.42
# 8      0.00
# 9     53.89
# 10    38.07
# 11    53.58
# 12    53.58
# 13    54.19
# 14    54.94
# 15    46.22
# 16     0.00
# 17    39.34
# 18    45.97
# 19    29.21
# 20    51.46
# 21    35.48
# 22    59.46
# 23    51.53
# 24    63.88
# 25    54.04
# 26    53.02
# 27    60.51
# 28    45.99
# 29    45.99
# 30    42.51
# 31    52.39
# 32    52.12
# 33    58.72
# 34    44.86
# 35    45.07
# 36    50.13
# 37    43.31
# 38    43.35
# 39    48.64
# 40    44.13
# 41    60.10
# 42    54.51
# 43    41.09
# 44    56.75
# 45    69.77
# 46    51.59
# 47    38.81
# 48    51.45
# 49    54.02
# 50    40.16
# 51    30.04
# 52    82.23
# 53    55.23
# 54    48.26
# 55    55.92
# 56    37.74
# 57    29.11
# 58     0.00
# 59    46.92
# 60    43.74
# 61    49.16
# 62    59.67
# 63    44.77
# 64    60.02
# 65    25.59
# 66    55.23
# Name: SR, dtype: float64

# %%
df[df["Player"] == "ED Weekes (WI)"]
# Out:
#            Player       Span  Mat  Inns  NO  Runs   HS    Ave   BF  SR  100  \
# 8  ED Weekes (WI)  1948-1958   48    81   5  4455  207  58.61  NaN NaN   15
#
#    50  0    4s 6s
# 8  19  6  258+  2

# %%
df[df.duplicated()]
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave      BF  \
# 12       GS Sobers (WI)  1954-1974   93   160  21  8032  365*  57.78   4063+
# 29  Javed Miandad (PAK)  1976-1993  124   189  21  8832  280*  52.57  15164+
# 66        V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29   15708
#
#        SR  100  50   0    4s   6s
# 12  53.58   26  30  12  593+  32+
# 29  45.99   23  43   6  788+   48
# 66  55.23   29  29  14   966   24

# %%
df[df.duplicated()==1]
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave      BF  \
# 12       GS Sobers (WI)  1954-1974   93   160  21  8032  365*  57.78   4063+
# 29  Javed Miandad (PAK)  1976-1993  124   189  21  8832  280*  52.57  15164+
# 66        V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29   15708
#
#        SR  100  50   0    4s   6s
# 12  53.58   26  30  12  593+  32+
# 29  45.99   23  43   6  788+   48
# 66  55.23   29  29  14   966   24

# %%
df[df["Player"] == "Javed Miandad (PAK)"]
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave      BF  \
# 28  Javed Miandad (PAK)  1976-1993  124   189  21  8832  280*  52.57  15164+
# 29  Javed Miandad (PAK)  1976-1993  124   189  21  8832  280*  52.57  15164+
#
#        SR  100  50  0    4s  6s
# 28  45.99   23  43  6  788+  48
# 29  45.99   23  43  6  788+  48

# %%
df[df["Player"].isin(["GS Sobers (WI)","Javed Miandad (PAK)","V Kohli (IND)"])]
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave      BF  \
# 11       GS Sobers (WI)  1954-1974   93   160  21  8032  365*  57.78   4063+
# 28  Javed Miandad (PAK)  1976-1993  124   189  21  8832  280*  52.57  15164+
# 53        V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29   15708
#
#        SR  100  50   0    4s   6s
# 11  53.58   26  30  12  593+  32+
# 28  45.99   23  43   6  788+   48
# 53  55.23   29  29  14   966   24

# %%
df = df.drop_duplicates()
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 8             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 9            SPD Smith (AUS)  2010-2023  102   181  22   9320   239  58.61
# 10          WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# ...

# %%
df[df["Player"].isin(["GS Sobers (WI)","Javed Miandad (PAK)","V Kohli (IND)"])]
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave      BF  \
# 11       GS Sobers (WI)  1954-1974   93   160  21  8032  365*  57.78   4063+
# 28  Javed Miandad (PAK)  1976-1993  124   189  21  8832  280*  52.57  15164+
# 53        V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29   15708
#
#        SR  100  50   0    4s   6s
# 11  53.58   26  30  12  593+  32+
# 28  45.99   23  43   6  788+   48
# 53  55.23   29  29  14   966   24

# %%
"Kanwal_Shehzadi".split("_")
# Out:
# ['Kanwal', 'Shehzadi']

# %%
df["Span"].str.split("-")
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 5     [1924, 1935]
# 6     [1931, 1939]
# 7     [1955, 1968]
# 8     [1948, 1958]
# 9     [2010, 2023]
# 10    [1927, 1947]
# 11    [1954, 1974]
# 13    [2000, 2015]
# 14    [2019, 2023]
# 15    [1908, 1930]
# 16    [1948, 1960]
# 17    [1937, 1955]
# 18    [1995, 2013]
# 19    [1921, 1929]
# 20    [2010, 2023]
# 21    [1968, 1973]
# 22    [1993, 1995]
# 23    [1970, 1984]
# 24    [1935, 1951]
# 25    [1989, 2013]
# 26    [2018, 2023]
# 27    [1990, 2006]
# 28    [1976, 1993]
# 30    [1996, 2012]
# 31    [1998, 2010]
# 32    [2000, 2017]
# 33    [1995, 2012]
# 34    [1920, 1929]
# 35    [1992, 2002]
# 36    [2005, 2013]
# 37    [1994, 2015]
# 38    [1971, 1987]
# 39    [1985, 2004]
# 40    [2021, 2023]
# 41    [1994, 2009]
# 42    [2004, 2018]
# 43    [1978, 1994]
# 44    [2012, 2023]
# 45    [1974, 1991]
# 46    [2021, 2023]
# 47    [1937, 1957]
# 48    [1997, 2014]
# ...

# %%
df["Span"]=df["Span"].str.split("-").str[0]
df["Span"]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3164\3491649691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Span"]=df["Span"].str.split("-").str[0]
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 61    1965
# 62    2002
# 63    1924
# 64    1930
# 65    1928
# Name: Span, Length: 64, dtype: object

# %%
df['Span'].str.split("-")[0]
# Out:
# ['1928']

# %%
df['Span'].str.split("-").str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1954
# 5     1935
# 6     1939
# 7     1968
# 8     1958
# 9     2023
# 10    1947
# 11    1974
# 13    2015
# 14    2023
# 15    1930
# 16    1960
# 17    1955
# 18    2013
# 19    1929
# 20    2023
# 21    1973
# 22    1995
# 23    1984
# 24    1951
# 25    2013
# 26    2023
# 27    2006
# 28    1993
# 30    2012
# 31    2010
# 32    2017
# 33    2012
# 34    1929
# 35    2002
# 36    2013
# 37    2015
# 38    1987
# 39    2004
# 40    2023
# 41    2009
# 42    2018
# 43    1994
# 44    2023
# 45    1991
# 46    2023
# 47    1957
# 48    2014
# 49    2007
# 50    1963
# 51    1928
# 52    2013
# 53    2023
# 54    2021
# 55    2015
# 56    1966
# 57    1949
# 58    1905
# 59    2013
# 60    1963
# 61    1981
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# Name: Span, dtype: object

# %%
df.drop(["Span"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df.drop(["Span"])
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df.drop(["Span"],axis=1)
# Out:
#                       Player  Mat  Inns  NO   Runs    HS    Ave      BF  \
# 0           DG Bradman (AUS)   52    80  10   6996   334  99.94   9800+
# 1             HC Brook (ENG)   12    20   1   1181   186  62.15    1287
# 2             AC Voges (AUS)   20    31   7   1485  269*  61.87    2667
# 3            RG Pollock (SA)   23    41   4   2256   274  60.97   1707+
# 4            GA Headley (WI)   22    40   4   2190  270*  60.83    416+
# 5          H Sutcliffe (ENG)   54    84   9   4555   194  60.73   6558+
# 6            E Paynter (ENG)   20    31   5   1540   243  59.23   1288+
# 7        KF Barrington (ENG)   82   131  15   6806   256  58.67   4957+
# 8             ED Weekes (WI)   48    81   5   4455   207  58.61     NaN
# 9            SPD Smith (AUS)  102   181  22   9320   239  58.61   17292
# 10          WR Hammond (ENG)   85   140  16   7249  336*  58.45   7491+
# 11            GS Sobers (WI)   93   160  21   8032  365*  57.78   4063+
# ...

# %%
pd.reset_option("display.max_rows",None)

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 66      V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29  15708
#
#        SR  100  50   0    4s  6s  start   end  career_length
# ...

# %%
df["Player"].str.split("(")
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# 66        [V Kohli , IND)]
# Name: Player, Length: 67, dtype: object

# %%
df["Country"] = df["Player"].str.split(pat="(").str[1]

# %%
df["Country"]
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# 66       IND)
# Name: Country, Length: 67, dtype: object

# %%
df['Country'] = df["Country"].str.split(pat=")").str[0]
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# 66       IND
# Name: Country, Length: 67, dtype: object

# %%
df.dtypes
# Out:
# Player            object
# Span              object
# Mat                int64
# Inns               int64
# NO                 int64
# Runs               int64
# HS                object
# Ave              float64
# BF                object
# SR               float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# start              int32
# end                int32
# career_length      int32
# Country           object
# dtype: object

# %%
text = "***Important Text***"
text.strip("*")
# Out:
# 'Important Text'

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 66      V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29  15708
#
#        SR  100  50   0    4s  6s  start   end  career_length Country
# ...

# %%
df["HS"].str.strip("*")
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: HS, Length: 64, dtype: object

# %%
df.dtypes
# Out:
# Player      object
# Span        object
# Mat          int64
# Inns         int64
# NO           int64
# Runs         int64
# HS          object
# Ave        float64
# BF          object
# SR         float64
# 100          int64
# 50           int64
# 0            int64
# 4s          object
# 6s          object
# Country     object
# dtype: object

# %%
df["HS"] = df["HS"].str.strip('*')
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3164\3399600901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HS"] = df["HS"].str.strip('*')
#                Player       Span  Mat  Inns  NO  Runs   HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996  334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181  186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256  274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270  60.83   416+
# ..                ...        ...  ...   ...  ..   ...  ...    ...    ...
# ...

# %%
df["HS"]=df["HS"].str.strip("*")

# %%
df['HS']=df["HS"].astype('int')

# %%
df.dtypes
# Out:
# Player      object
# Span        object
# Mat          int64
# Inns         int64
# NO           int64
# Runs         int64
# HS           int32
# Ave        float64
# BF          object
# SR         float64
# 100          int64
# 50           int64
# 0            int64
# 4s          object
# 6s          object
# Country     object
# dtype: object

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 66      V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29  15708
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df["start"]=df["Span"].str.split("-").str[0]
df["end"]=df["Span"].str.split("-").str[1]
df["start"]
df["end"]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1954
#       ...
# 62    2014
# 63    1934
# 64    1938
# 65    1934
# 66    2023
# Name: end, Length: 67, dtype: object

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 66      V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29  15708
#
#        SR  100  50   0    4s  6s start   end
# ...

# %%
df=df.astype({'start':'int','end':'int'})

# %%
df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF         object
# SR        float64
# 100         int64
# 50          int64
# 0           int64
# 4s         object
# 6s         object
# start       int32
# end         int32
# dtype: object

# %%
df["career_length"]=df["end"]-df["start"]
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 66      V Kohli (IND)  2011-2023  111   187  11  8676  254*  49.29  15708
#
#        SR  100  50   0    4s  6s  start   end  career_length
# ...

# %%
round(df["career_length"].mean(),2)
# Out:
# 12.91

# %%
round(df[df["start"]>2010]["SR"].mean(),2)
# Out:
# 56.66

# %%
df[df["start"]<1960]['Player'].count()
# Out:
# 24

# %%
df.groupby("Country")["HS"].mean().to_frame("Highest Inning Score")
# Out:
#          Highest Inning Score
# Country
# AUS                251.500000
# ENG                222.846154
# ICC/IND            294.500000
# ICC/PAK            329.000000
# ICC/SA             250.500000
# ICC/WI             400.000000
# IND                243.800000
# NZ                 213.666667
# PAK                252.000000
# SA                 223.200000
# SL                 308.000000
# WI                 262.777778
# ZIM                232.000000

# %%
round(df.groupby("Country")[["100","50","0"]].mean(),2)
# Out:
#            100     50      0
# Country
# AUS      20.62  28.00   8.50
# ENG      12.31  20.77   4.31
# ICC/IND  29.50  47.50  12.00
# ICC/PAK  25.00  46.00  15.00
# ICC/SA   36.00  48.00  13.50
# ICC/WI   34.00  48.00  17.00
# IND      29.40  34.80  11.40
# NZ       12.33  16.33   4.33
# PAK      18.67  26.50   7.67
# SA        9.80  20.20   3.40
# SL       28.67  44.00  12.33
# WI       17.67  26.11   7.78
# ZIM      12.00  27.00   5.00
